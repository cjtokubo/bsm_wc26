# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sys
import requests
from io import BytesIO
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
from PIL import Image
import os
import numpy as np

sys.path.append('..')
from wc26_data import get_wc26_data, get_country_rankings, get_player_data, get_ids, get_play_by_play
# Out:
# /Users/chancetokubo/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
matches = get_ids('/Users/chancetokubo/bad.sports.metrics/matches.txt')

# %%
team_data = get_wc26_data(matches)
player_data = get_player_data(matches)
pbp = get_play_by_play(matches)

team_data.to_csv('/Users/chancetokubo/bad.sports.metrics/dataframes/team_data.csv')
player_data.to_csv('/Users/chancetokubo/bad.sports.metrics/dataframes/player_data.csv')
pbp.to_csv('/Users/chancetokubo/bad.sports.metrics/dataframes/pbp.csv')
# Out:
# Approximate time of data pulling completion: 624.0 seconds.
# Dataframe Complete
# Estimated data pulling time 432.0
# estimated time: 432.0 seconds
