# %%
from wc26_data import get_wc26_data, get_country_rankings
import pandas as pd

# %%
matches = [400021443, 400021441, 400021449, 400021458, 400021447, 400021456, 400021453, 400021463, 400021464, 400021470, 400021467, 400021474, 400021482,
           400021478, 400021486, 400021476, 400021490, 400021488]

# %%
my_data = get_wc26_data(matches=matches)
# Out:
# Approximate time of data pulling completion: 108 seconds.
# Status Code: 200
# sleeping for 3
# 200
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/Users/chancetokubo/Library/Python/3.9/lib/python/site-packages/IPython/core/interactiveshell.py", line 3550, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/vl/tq28lccn1d19hq22zfhh94lc0000gn/T/ipykernel_40458/1282906028.py", line 1, in <module>
#     my_data = get_wc26_data(matches=matches)
#   File "/Users/chancetokubo/bad.sports.metrics/wc_1/wc26_data.py", line 81, in get_wc26_data
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/chancetokubo/Library/Python/3.9/lib/python/site-packages/IPython/core/interactiveshell.py", line 2144, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
# ...

# %%
my_data.tail()
# Out:
#                     Date    Group        Stage TeamID     TeamName TeamAbbr  \
# 31  2026-06-16T01:00:00Z  Group G  First Stage  43978  New Zealand      NZL
# 32  2026-06-16T19:00:00Z  Group I  First Stage  43946       France      FRA
# 33  2026-06-16T19:00:00Z  Group I  First Stage  43879      Senegal      SEN
# 34  2026-06-16T22:00:00Z  Group I  First Stage  43818         Iraq      IRQ
# 35  2026-06-16T22:00:00Z  Group I  First Stage  43961       Norway      NOR
#
#    Formation    IdMatch  GameNum StatsId  ...  SubstitutionsIn  \
# 31     4-4-2  400021476       15  151644  ...              5.0
# 32   4-2-3-1  400021490       17  151656  ...              2.0
# 33     4-3-3  400021490       17  151656  ...              5.0
# 34     4-4-2  400021488       18  151655  ...              5.0
# 35   4-1-2-3  400021488       18  151655  ...              5.0
#
#     SubstitutionsOut  TakeOnsCompleted  Threat  ThrowIns  TimePlayed  \
# ...
